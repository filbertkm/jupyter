# %%
import pandas as pd

# %%
df = pd.read_csv('data/restaurant_inspections.csv')

# %%
# cleanup zipcodes
df = df.dropna(axis=0, subset=['ZIPCODE'])
df['ZIPCODE'] = df['ZIPCODE'].astype(int).astype(str).str.zfill(5)

df.head()
# Out:
#    Unnamed: 0     CAMIS                   DBA           BORO BUILDING  \
# 0           2  50053100         NEW TUNG HING       Brooklyn     5224
# 1           4  50088953     AZOGUENITA BAKERY         Queens     3761
# 2           6  50115617           BURGER KING       Brooklyn     5212
# 3           8  50065696        RUTA DEL SABOR  Staten Island     1278
# 4           9  50037780  MILLE-FEUILLE BAKERY      Manhattan     2175
#
#              STREET ZIPCODE       PHONE       CUISINE DESCRIPTION  \
# 0          4 AVENUE   11220  9176370007                   Chinese
# 1          103RD ST   11368  7184240119  Bakery Products/Desserts
# 2          5 AVENUE   11220  7187650844                Hamburgers
# 3  CASTLETON AVENUE   10310  7184470930                   Mexican
# 4          BROADWAY   10024  2123626261                    French
#
#   INSPECTION DATE  ...                                INSPECTION TYPE  \
# 0      07/19/2021  ...          Cycle Inspection / Initial Inspection
# ...

# %%
df['DATE'] = pd.to_datetime(df['INSPECTION DATE'])
df = df.query('DATE >= 20220101')
df = df.sort_values(by=['DATE'], ascending=False)
df.head()
# Out:
#        Unnamed: 0     CAMIS                 DBA      BORO BUILDING  \
# 59876      221989  50082114  ANGELITOS DE NOCHE  Brooklyn      263
# 39108      145320  50082114  ANGELITOS DE NOCHE  Brooklyn      263
# 813          3180  50082114  ANGELITOS DE NOCHE  Brooklyn      263
# 50364      187236  50082114  ANGELITOS DE NOCHE  Brooklyn      263
# 26350       98315  50082114  ANGELITOS DE NOCHE  Brooklyn      263
#
#               STREET ZIPCODE       PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 59876  KINGS HIGHWAY   11223  9174999939            American      06/11/2022
# 39108  KINGS HIGHWAY   11223  9174999939            American      06/11/2022
# 813    KINGS HIGHWAY   11223  9174999939            American      06/11/2022
# 50364  KINGS HIGHWAY   11223  9174999939            American      06/11/2022
# 26350  KINGS HIGHWAY   11223  9174999939            American      06/11/2022
#
#        ...                               INSPECTION TYPE   Latitude  \
# ...

# %%
pd.set_option('display.max_rows', 100)

dfCuisine = df.groupby(by='CUISINE DESCRIPTION').size().reset_index(name='counts')
dfCuisine.sort_values(by='counts', ascending=False)
# Out:
#                CUISINE DESCRIPTION  counts
# 2                         American    7768
# 16                         Chinese    4695
# 63                           Pizza    3468
# 19                      Coffee/Tea    2937
# 49                  Latin American    2006
# 7         Bakery Products/Desserts    2000
# 52                         Mexican    1939
# 44                         Italian    1711
# 13                       Caribbean    1649
# 45                        Japanese    1637
# 77                         Spanish    1399
# 14                         Chicken    1341
# 68                      Sandwiches    1238
# 24                          Donuts     996
# 47  Juice, Smoothies, Fruit Salads     846
# 36                      Hamburgers     737
# 81                            Thai     708
# 46                   Jewish/Kosher     706
# 4               Asian/Asian Fusion     696
# 40                          Indian     651
# 80                         Tex-Mex     633
# ...

# %%
dfBoro = df.groupby(by='BORO').size().reset_index(name='counts')
dfBoro.sort_values(by='counts', ascending=False)
# Out:
#             BORO  counts
# 3      Manhattan   18114
# 2       Brooklyn   14131
# 4         Queens   10841
# 1          Bronx    4266
# 5  Staten Island    1518
# 0              0       5

# %%
print(df['CUISINE DESCRIPTION'].unique())
# Out:
# ['American' 'Bangladeshi' 'Caribbean' 'Tex-Mex' 'Bakery Products/Desserts'
#  'Other' 'Chicken' 'Coffee/Tea' 'Spanish' 'Mexican' 'Latin American'
#  'Middle Eastern' 'Mediterranean' 'Hamburgers' 'African'
#  'Juice, Smoothies, Fruit Salads' 'Indian' 'Thai' 'Sandwiches' 'Creole'
#  'Pizza' 'French' 'Chinese' 'Italian' 'Australian' 'Eastern European'
#  'Jewish/Kosher' 'Japanese' 'Sandwiches/Salads/Mixed Buffet' 'Donuts'
#  'Vegetarian' 'Asian/Asian Fusion' 'Vegan' 'Tapas' 'Korean'
#  'Bagels/Pretzels' 'Bottled Beverages' 'Russian' 'Seafood'
#  'Frozen Desserts' 'Peruvian' 'Southeast Asian'
#  'Not Listed/Not Applicable' 'Soups/Salads/Sandwiches' 'Hawaiian'
#  'Fruits/Vegetables' 'Chinese/Japanese' 'Turkish' 'Pancakes/Waffles'
#  'Steakhouse' 'Barbecue' 'Continental' 'Pakistani' 'Soul Food' 'Afghan'
#  'Greek' 'Brazilian' 'Salads' 'Filipino' 'Ethiopian' 'Irish' 'Hotdogs'
#  'Hotdogs/Pretzels' 'Polish' 'Portuguese' 'Indonesian' 'New American'
# ...

# %%
df.query('ZIPCODE == "10004"')
# Out:
#        Unnamed: 0     CAMIS                    DBA       BORO BUILDING  \
# 13641       50742  50032842          RETRO FITNESS  Manhattan        1
# 64858      240391  50113553              POKE BOWL  Manhattan       80
# 30343      112985  41009267      UNDERGROUND PIZZA  Manhattan        2
# 58424      216729  41009267      UNDERGROUND PIZZA  Manhattan        2
# 25455       94952  41363485           LEO'S BAGELS  Manhattan        3
# ...           ...       ...                    ...        ...      ...
# 16960       63099  50117920       ARAMARK @ FISERV  Manhattan        1
# 39825      148173  50111125  AMERICAN BREW + PRESS  Manhattan        4
# 29472      109802  50114976             787 COFFEE  Manhattan       66
# 68893      255158  50114976             787 COFFEE  Manhattan       66
# 50015      185899  50111125  AMERICAN BREW + PRESS  Manhattan        4
#
#                STREET ZIPCODE       PHONE             CUISINE DESCRIPTION  \
# ...
